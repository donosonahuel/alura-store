# %% [markdown]
# <a href="https://colab.research.google.com/github/donosonahuel/alura-store/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
def facturacion(f):
  ingresoTotal = f['Precio'].sum()
  return ingresoTotal

# %%
print(f"El ingreso total de la tienda es: ${facturacion(tienda):,.2f}")
print("\n")
print(f"El ingreso total de la tienda 2 es: ${facturacion(tienda2):,.2f}")
print("\n")
print(f"El ingreso total de la tienda 3 es: ${facturacion(tienda3):,.2f}")
print("\n")
print(f"El ingreso total de la tienda 4 es: ${facturacion(tienda4):,.2f}")
# Out:
# El ingreso total de la tienda es: $1,150,880,400.00
#
#
# El ingreso total de la tienda 2 es: $1,116,343,500.00
#
#
# El ingreso total de la tienda 3 es: $1,098,019,600.00
#
#
# El ingreso total de la tienda 4 es: $1,038,375,700.00

# %% [markdown]
# # 2. Ventas por categoría

# %%
def listarCategoria(lc):
  categorias = []
  for categoria in lc['Categoría del Producto']:
    if categoria not in categorias:
      categorias.append(categoria)

  return categorias


def totalCategoria(tc):
  categorias = listarCategoria(tc)
  conteo = {}

  for cat in categorias:
    contador = 0
    for i in range(len(tc)):
      if tc['Categoría del Producto'][i] == cat:
        contador += 1
    conteo[cat] = contador

  return conteo


def popularCategoria(pc):
  categoriasConteo = totalCategoria(pc)
  maxCantidad = -1
  categoriaPopular = None

  for cat, cantidad in categoriasConteo.items():
    if cantidad > maxCantidad:
      maxCantidad = cantidad
      categoriaPopular = cat

  return categoriaPopular

# %%
print("Tienda Categorías: ", listarCategoria(tienda))
print("Tienda Total Categorías: ", totalCategoria(tienda))
print("Tienda Categoría Popular: ", popularCategoria(tienda))
print("\n")
print("Tienda 2 Categorías: ", listarCategoria(tienda2))
print("Tienda 2 Total Categorías: ", totalCategoria(tienda2))
print("Tienda 2 Categoría Popular: ", popularCategoria(tienda2))
print("\n")
print("Tienda 3 Categorías: ", listarCategoria(tienda3))
print("Tienda 3 Total Categorías: ", totalCategoria(tienda3))
print("Tienda 3 Categoría Popular: ", popularCategoria(tienda3))
print("\n")
print("Tienda 4 Categorías: ", listarCategoria(tienda4))
print("Tienda 4 Total Categorías: ", totalCategoria(tienda4))
print("Tienda 4 Categoría Popular: ", popularCategoria(tienda4))
# Out:
# Tienda Categorías:  ['Electrónicos', 'Muebles', 'Juguetes', 'Electrodomésticos', 'Artículos para el hogar', 'Deportes y diversión', 'Libros', 'Instrumentos musicales']
# Tienda Total Categorías:  {'Electrónicos': 448, 'Muebles': 465, 'Juguetes': 324, 'Electrodomésticos': 312, 'Artículos para el hogar': 171, 'Deportes y diversión': 284, 'Libros': 173, 'Instrumentos musicales': 182}
# Tienda Categoría Popular:  Muebles
#
#
# Tienda 2 Categorías:  ['Muebles', 'Instrumentos musicales', 'Deportes y diversión', 'Electrónicos', 'Artículos para el hogar', 'Juguetes', 'Electrodomésticos', 'Libros']
# Tienda 2 Total Categorías:  {'Muebles': 442, 'Instrumentos musicales': 224, 'Deportes y diversión': 275, 'Electrónicos': 422, 'Artículos para el hogar': 181, 'Juguetes': 313, 'Electrodomésticos': 305, 'Libros': 197}
# Tienda 2 Categoría Popular:  Muebles
#
#
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
def totalCalificacion(tcf):
  calificacionTotal = tcf['Calificación'].sum()
  return calificacionTotal


def promedioCalificacion(pcf):
  calificacionTotal = totalCalificacion(pcf)
  promedio = calificacionTotal / len(pcf)
  return round(promedio, 2)

# %%
print("Total de puntos de tienda: ", totalCalificacion(tienda))
print("Promedio de calificacion de tienda: ", promedioCalificacion(tienda))
print("\n")
print("Total de puntos de tienda 2: ", totalCalificacion(tienda2))
print("Promedio de calificacion de tienda 2: ", promedioCalificacion(tienda2))
print("\n")
print("Total de puntos de tienda 3: ", totalCalificacion(tienda3))
print("Promedio de calificacion de tienda 3: ", promedioCalificacion(tienda3))
print("\n")
print("Total de puntos de tienda 4: ", totalCalificacion(tienda4))
print("Promedio de calificacion de tienda4: ", promedioCalificacion(tienda4))
# Out:
# Total de puntos de tienda:  9381
# Promedio de calificacion de tienda:  3.98
#
#
# Total de puntos de tienda 2:  9524
# Promedio de calificacion de tienda 2:  4.04
#
#
# Total de puntos de tienda 3:  9550
# Promedio de calificacion de tienda 3:  4.05
#
#
# Total de puntos de tienda 4:  9422
# Promedio de calificacion de tienda4:  4.0

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
def productosValorados(pv):
  categoriasValor = totalCategoria(pv)
  maxCantidad = -1

  categoriaPopular = None


  for cat, cantidad in categoriasValor.items():
    if cantidad > maxCantidad:
      maxCantidad = cantidad
      categoriaPopular = cat

  return [categoriaPopular, maxCantidad]


def productosMenosValorados(pmv):
  categoriasValor = totalCategoria(pmv)
  minCantidad = 1000000
  categoriaMenosPopular = None

  for cat, cantidad in categoriasValor.items():
      if cantidad < minCantidad:
        minCantidad = cantidad
        categoriaMenosPopular = cat

  return [categoriaMenosPopular, minCantidad]

# %%
print(f"Tienda: Lo mas valorado es {productosValorados(tienda)} y lo menos valorado es {productosMenosValorados(tienda)}")
print("\n")
print(f"Tienda 2: Lo mas valorado es {productosValorados(tienda2)} y lo menos valorado es {productosMenosValorados(tienda2)}")
print("\n")
print(f"Tienda 3: Lo mas valorado es {productosValorados(tienda3)} y lo menos valorado es {productosMenosValorados(tienda3)}")
print("\n")
print(f"Tienda 4: Lo mas valorado es {productosValorados(tienda4)} y lo menos valorado es {productosMenosValorados(tienda4)}")
print("\n")
# Out:
# Tienda: Lo mas valorado es ['Muebles', 465] y lo menos valorado es ['Artículos para el hogar', 171]
#
#
# Tienda 2: Lo mas valorado es ['Muebles', 442] y lo menos valorado es ['Artículos para el hogar', 181]
#
#
# Tienda 3: Lo mas valorado es ['Muebles', 499] y lo menos valorado es ['Instrumentos musicales', 177]
#
#
# Tienda 4: Lo mas valorado es ['Muebles', 480] y lo menos valorado es ['Instrumentos musicales', 170]

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
def totalEnvio(te):
  enviosTotal = te['Costo de envío'].sum()
  return enviosTotal


def promedioEnvio(pe):
  envioTotal = totalEnvio(pe)
  promedioEntrega = envioTotal / len(pe)
  return round(promedioEntrega, 2)

# %%
print("Total de envío de tienda: ", totalEnvio(tienda))
print("Promedio de envío de tienda: ", promedioEnvio(tienda))
print("\n")
print("Total de envío de tienda 2: ", totalEnvio(tienda2))
print("Promedio de envío de tienda 2: ", promedioEnvio(tienda2))
print("\n")
print("Total de envío de tienda 3: ", totalEnvio(tienda3))
print("Promedio de envío de tienda 3: ", promedioEnvio(tienda3))
print("\n")
print("Total de envío de tienda 4: ", totalEnvio(tienda4))
print("Promedio de envío de tienda 4: ", promedioEnvio(tienda4))
# Out:
# Total de envío de tienda:  61377900.0
# Promedio de envío de tienda:  26018.61
#
#
# Total de envío de tienda 2:  59485100.0
# Promedio de envío de tienda 2:  25216.24
#
#
# Total de envío de tienda 3:  58516600.0
# Promedio de envío de tienda 3:  24805.68
#
#
# Total de envío de tienda 4:  55317400.0
# Promedio de envío de tienda 4:  23459.46

# %% [markdown]
# # 6. Graficos Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Productos mas y menos vendidos

# %%
tiendas = [tienda, tienda2, tienda3, tienda4]
nombres_tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]

mas_vendidos = [productosValorados(tienda)[1] for tienda in tiendas]
menos_vendidos = [productosMenosValorados(tienda)[1] for tienda in tiendas]

categorias_mas = [productosValorados(tienda)[0] for tienda in tiendas]
categorias_menos = [productosMenosValorados(tienda)[0] for tienda in tiendas]

plt.figure(figsize=(10, 6))
bar_width = 0.35
indices = np.arange(len(tiendas))

plt.bar(indices, mas_vendidos, width=bar_width, color='#2ecc71', label='Más vendido')
plt.bar(indices + bar_width, menos_vendidos, width=bar_width, color='#e74c3c', label='Menos vendido')

plt.title('Productos Más y Menos Vendidos por Tienda')
plt.xlabel('Tiendas')
plt.ylabel('Cantidad de Productos')
plt.xticks(indices + bar_width/2, nombres_tiendas)

plt.legend()

for i in range(len(tiendas)):
    plt.text(indices[i], mas_vendidos[i] + 5, categorias_mas[i], ha='center', fontsize=9)
    plt.text(indices[i] + bar_width, menos_vendidos[i] + 5, categorias_menos[i], ha='center', fontsize=9)

plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.tight_layout()

plt.show()

# %% [markdown]
# Calificación promedio de la tienda

# %%
tiendas = [tienda, tienda2, tienda3, tienda4]
nombres_tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]

promedios = [promedioCalificacion(tienda) for tienda in tiendas]

colores = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99']

plt.figure(figsize=(8, 8))
plt.title('Promedio de Calificación por Tienda', fontsize=16)

plt.pie(
    promedios,
    labels=nombres_tiendas,
    colors=colores,
    autopct='%1.1f%%',
    startangle=90,
    explode=(0.05, 0.05, 0.05, 0.05)
)

leyenda = [f"{nombre}: {promedio}" for nombre, promedio in zip(nombres_tiendas, promedios)]
plt.legend(leyenda, title="Calificaciones", bbox_to_anchor=(1, 0.5), loc='center left')

plt.tight_layout()
plt.show()

# %% [markdown]
# Envío promedio por tienda

# %%
promedios_envio = [promedioEnvio(tienda) for tienda in [tienda, tienda2, tienda3, tienda4]]
nombres_tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]

plt.figure(figsize=(10, 5))
bars = plt.barh(nombres_tiendas, promedios_envio, color='#3498db', height=0.6)

plt.title('Promedio de Costo de Envío por Tienda', pad=20)
plt.xlabel('Costo Promedio ($)')
plt.grid(axis='x', linestyle='--', alpha=0.6)

for bar in bars:
    width = bar.get_width()
    plt.text(width + 100, bar.get_y() + 0.3, f"${width:.2f}", va='center')

plt.tight_layout()
plt.show()

# %% [markdown]
# Ventas por categoría

# %%
tiendas = [tienda, tienda2, tienda3, tienda4]
nombres_tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]

categorias = set()
for df in tiendas:
    categorias.update(totalCategoria(df).keys())
categorias = sorted(categorias)

ventas_por_tienda = []
for df in tiendas:
    conteo = totalCategoria(df)
    ventas = [conteo.get(cat, 0) for cat in categorias]
    ventas_por_tienda.append(ventas)

plt.figure(figsize=(12, 7))
colores = plt.colormaps['tab20'].resampled(len(categorias))

bottom = np.zeros(len(nombres_tiendas))

for i, cat in enumerate(categorias):
    valores = [ventas[i] for ventas in ventas_por_tienda]
    barras = plt.bar(
        nombres_tiendas,
        valores,
        bottom=bottom,
        color=colores(i),
        label=cat,
        edgecolor='white'
    )
    bottom += valores

plt.title('Ventas por Categoría (Apiladas por Tienda)', pad=20, fontsize=15)
plt.xlabel('Tiendas', fontsize=12)
plt.ylabel('Cantidad de Productos Vendidos', fontsize=12)
plt.legend(title='Categorías', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(axis='y', linestyle='--', alpha=0.4)

for i, total in enumerate(bottom):
    plt.text(i, total + 5, f"Total: {int(total)}", ha='center')

plt.tight_layout()
plt.show()

# %% [markdown]
# Analisis de facturación

# %%
facturacion = [
    tienda['Precio'].sum(),
    tienda2['Precio'].sum(),
    tienda3['Precio'].sum(),
    tienda4['Precio'].sum()
]

tiendas = ["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]

plt.figure(figsize=(12, 6))
bars = plt.barh(tiendas, facturacion, color='#3498db', height=0.6)

promedio = np.mean(facturacion)
plt.axvline(promedio, color='#e74c3c', linestyle='--', linewidth=2,
            label=f'Promedio: ${promedio:,.2f}')

for bar in bars:
    width = bar.get_width()
    plt.text(width + 10000, bar.get_y() + bar.get_height()/2,
             f"${width:,.2f}",
             va='center', ha='left', fontsize=10)

plt.title('Facturación Total por Tienda', pad=20, fontsize=16)
plt.xlabel('Facturación ($)', fontsize=12)
plt.ylabel('Tiendas', fontsize=12)
plt.legend(loc='lower right')
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.tight_layout()

plt.savefig('facturacion_tiendas.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # 7. Informe Final

# %% [markdown]
# ### **Informe Final: Recomendación de Tienda para el Sr. Juan**
#
# #### **Introducción**
# Este informe analiza el desempeño de las cuatro tiendas en base a cinco métricas clave: **facturación total**, **ventas por categoría**, **calificación promedio de clientes**, **productos más/menos vendidos** y **costos de envío promedio**. El objetivo es recomendar al Sr. Juan qué tienda priorizar para su estrategia comercial.
#
# ---
#
# ### **Análisis Comparativo**
#
# #### 1. **Facturación Total**
# - **Tienda 1**: $1,150,880,400
#
# - **Tienda 2**: $1,116,343,500
#
# - **Tienda 3**: $1,098,019,600
#
# - **Tienda 4**: $1,038,375,700
# **→ La Tienda 1 lidera en ingresos**, pero la diferencia con la Tienda 3 es mínima (4.8%).
#
# #### 2. **Ventas por Categoría**
# - **Categoría más vendida**: *Muebles* (destaca en todas las tiendas).
# - **Categoría menos vendida**:
#   - Tiendas 1 y 2: *Artículos para el hogar*.
#   - Tiendas 3 y 4: *Instrumentos musicales*.
# **→ La Tienda 3 tiene el mayor volumen en muebles (499 unidades)**, indicando fuerte demanda en esta categoría.
#
# #### 3. **Calificación Promedio**
# - **Tienda 3**: 4.05 (la más alta).
# - Tienda 2: 4.04
# - Tienda 4: 4.0
# - Tienda 1: 3.98
# **→ La Tienda 3 tiene la mejor valoración de clientes**, lo que sugiere mayor satisfacción y fidelización.
#
# #### 4. **Productos Más/Menos Vendidos**
# - **Tienda 3**:
#   - Más vendido: *Muebles* (499 unidades).
#   - Menos vendido: *Instrumentos musicales* (177 unidades).
# **→ Alto rendimiento en muebles**, con margen para mejorar en instrumentos.
#
# #### 5. **Costo de Envío Promedio**
# - **Tienda 4**: $23,459.46 (el más bajo).
#
# - Tienda 3: $24,805.68
#
# - Tienda 2: $25,216.24
#
# - Tienda 1: $26,018.61
# **→ La Tienda 3 no es la más económica**, pero la diferencia con la Tienda 4 es marginal (5.7%).
#
# ---
#
# ### **Conclusión y Recomendación**
# **Tienda recomendada: Tienda 3**.
#
# #### **Razones clave**:
# 1. **Alto desempeño en muebles** (categoría estrella en todas las tiendas).
# 2. **Mejor calificación de clientes** (4.05), lo que indica menor riesgo de pérdida de clientes.
# 3. **Facturación competitiva**, cercana a la Tienda 1 pero con menores costos de envío que las Tiendas 1 y 2.
# 4. **Balance general**: Aunque la Tienda 4 tiene costos de envío más bajos, la Tienda 3 destaca en ingresos, satisfacción del cliente y volumen de ventas estratégicas (muebles).
#
# #### **Acciones sugeridas**:
# - **Potenciar la categoría de muebles** con promociones.
# - **Optimizar costos de envío** para competir con la Tienda 4.
# - **Monitorear instrumentos musicales**, su punto débil, con estrategias de liquidación o paquetes promocionales.
#
# ---
#
# **Nota**: Si el Sr. Juan prioriza **rentabilidad a corto plazo**, la Tienda 1 es alternativa. Pero para **sostenibilidad y crecimiento**, la Tienda 3 es la opción óptima.
#
# ---
